# %% [markdown]
# ## Auto run the FRC code for a sample set

# %% [markdown]
# This code will auto run through a suite of samples in the same folder. It assumes that in the working directory, there will be a folder called 'all_data', and within this folder, there are seperate site folders, e.g. 'HC1', 'HC2'...etc.
#
# It will then run through all of the stages laid out in the manual notebooks, with majority of the same prompts.

# %%
import Auto_frc_functions as pf
import time
import threading

# %%
# --- config: extensions to recognise for FRC

WANTED_EXTS = {
    '.frc': 'frc',   
    '.nrm': 'nrm',
    '.arm': 'arm',
    '.sirm': 'sirm'}

# %%
# run whole folder
res = pf.run_site()
# Out:
# Building index for site: HC3
# Found 10 unique sample base names in HC3.
#
# --- Processing sample hc3a ---
# Attempt 1 of running sample hc3a
# Input Curie temperature in °C: 300
# Pick the AF demag step where the primary component is identified: 0
# Selected AF step: 0
# Are all of the FWHM reliable? Enter Y or N: Y
# Input the lowest reliable SF from the FWHM graph above:2
# Do you want to change the maximum hc and/or hi value from max hc = 224 and min hi = -210 from the FORC file? (Y or N)N
# Elapsed Time 2 secondsEnter ARM bias field in microtesla (µT), e.g. 50: 200
# Elapsed Time 186 seconds
# Finished in 186.045 seconds
# AF Demag spectra for the NRM (use to pick the AF steps)
# AF field step 0 0.0001
# AF field step 1 3.0
# AF field step 2 6.0
# AF field step 3 9.0
# AF field step 4 12.0
# AF field step 5 15.0
# AF field step 6 20.0
# AF field step 7 25.0
# AF field step 8 30.0
# AF field step 9 40.0
# AF field step 10 50.0
# AF field step 11 70.0
# AF field step 12 100.0

# %% [markdown]
# ##
